# %%
import pandas as pd
import openpyxl

# %%
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cus = pd.read_excel('../dataset/Ecomm.xlsx',sheet_name='CustomerDetail')

# %%
ord = pd.read_excel('../dataset/Ecomm.xlsx',sheet_name='Jan')

# %%
cus.shape
# Out:
# (24, 12)

# %%
cus.head(3)
# Out:
#    CustomerID.1 Order Date MonthName   Customer Name State or Province  \
# 0          7253 2015-01-07       Jan   Bonnie Potter        Washington
# 1          4875 2015-06-13       Jun  Ronnie Proctor        California
# 2          2748 2015-02-15       Feb   Marcus Dunlap        New Jersey
#
#           City Gender.2
# 0    Anacortes     MALE
# 1  San Gabriel   FEMALE
# 2      Roselle     MALE

# %%
cus.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
cus = cus.rename(columns ={'CustomerID.1':'Customer','Gender.2':'Gender'})

# %%
cus = cus.drop(columns=['CustomerID','Month','DateInText','Gender.1','Gender']  )

# %%
ord.head(3)
# Out:
#    Order ID  CustomerID   Amount     Profit  Quantity Product Category  \
# 0     88522        4666    11.36     4.5600         4  Office Supplies
# 1     90193        4663  6011.76  4390.3665        12        Furniture
# 2     90192        2583   208.56   -53.8096        22        Furniture
#
#   Product Sub-Category Payment Mode
# 0  Pens & Art Supplies  Credit Card
# 1   Chairs & Chairmats  Credit Card
# 2   Office Furnishings  Credit Card

# %%
ord = ord.rename( columns = {'Quantity ordered new':'Quantity'})

# %%
ord.shape
# Out:
# (1952, 8)
